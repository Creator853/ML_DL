# %%
#Import the necessary libraries 
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error

# %%
#Load in the data and check the shapes
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
print("Shapes --> \n Train: ", train.shape ,"\n Test: ", test.shape)
# Out:
# Shapes -->
#  Train:  (1364, 36)
#  Test:  (341, 36)

# %%
train.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0     6.800000         0.037490   48.6034                       2004
# 1    15.600000         0.172597  114.8518                       1997
# 2    12.911575         0.054721  107.8254                       1985
# 3    11.800000         0.098312   81.4618                       1998
# 4    17.850000         0.046600  125.1388                       2004
#
#    Item_Outlet_Sales  Item_Fat_Content_LF  Item_Fat_Content_Low Fat  \
# 0           291.6204                    0                         1
# 1          2163.1842                    0                         1
# 2          2387.5588                    0                         1
# 3           161.1236                    0                         1
# 4          1981.4208                    0                         0
#
#    Item_Fat_Content_Regular  Item_Fat_Content_low fat  Item_Fat_Content_reg  \
# ...

# %%
#Separation of independent and dependent variables
train_x = train.drop(columns=["Item_Outlet_Sales"])
train_y = train["Item_Outlet_Sales"]
test_x = test.drop(columns=["Item_Outlet_Sales"])
test_y = test["Item_Outlet_Sales"]

# %%
#Let's re-confirm the number of dimensions on training data.
print('\nTraining model with {} dimensions.'.format(train_x.shape[1]))
# Out:
# Training model with 35 dimensions.

# %%
#Initilisation of Model Object
model = LinearRegression()
model.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
#Prediction on train and test data
print("Train: \n ", model.predict(train_x), " \n Test: \n ", model.predict(test_x))
# Out:
# Train:
#   [ 803.88817641 1733.98835979 3294.52154482 ...  811.16967914 2343.96927185
#  2444.98869913]
#  Test:
#   [ 1615.37962439  3168.60806673  2564.31326686  2685.29698657
#   2771.82059109  4223.3788671   2615.10827403   565.8088248
#   4000.68496927  1035.54578573  2184.60316447  1033.54185437
#    150.22804639  1616.19932803  2370.37858454  1953.693325
#   2307.09514556  1429.85271583  2343.42149697  3780.28905363
#    583.44339124  1089.08346168  2323.64661483  3559.90832258
#   1829.46789667  1602.03985138   840.70282292  1823.14253132
#   3145.30906529  1823.30397678  2103.35401623  3025.02597477
#   2265.03907268   697.33936172  4474.05156681  2270.45195749
#   1897.45212218  3305.0110824   2228.36615412  3767.90052861
#   2162.33844917   665.40410258  -926.22966666   738.30407877
#    197.90808777  2483.25075805  3693.05388376  2458.43116228
#   1329.02544771   -57.67123156  1952.26612825  3614.4167807
#   2127.22359714  2486.1932574   1826.90446272   786.7283994
# ...

# %%
#Accuracy on train and test data
print("Accuracy on train data: {} ".format(mean_squared_error(train_y, model.predict(train_x))**0.5))
print("Accuracy on test data: {}".format(mean_squared_error(test_y, model.predict(test_x))**0.5))
# Out:
# Accuracy on train data: 1135.8159344155245
# Accuracy on test data: 1009.2517232209709

# %% [markdown]
# Till now we were considering the simple linear regression model now let's try using PCA which stands for
# PRINCIPAL COMPONENT ANALYSIS
# As the name suggests we'll be performing a reduction in dimensionality of the dataset to find the dimensions due to which o/p is affected the most.

# %%
#Initialisation of PCA object
model_pca = PCA(n_components=12)
train1_x, test1_x = model_pca.fit_transform(train_x), model_pca.fit_transform(test_x)

#Let's find out the dimensions of new training and testing data
print("\nTraining: {}".format(train1_x.shape[1]),"\n Testing: {}".format(test1_x.shape[1]))
# Out:
# Training: 12
#  Testing: 12

# %%
#Now let's fit the model with new training data.
model1 = LinearRegression()
model1.fit(train1_x, train_y)
# Out:
# LinearRegression()

# %%
#Now lets make predictions on new training and testing data.
print("Predictions on Train: \n {}".format(model1.predict(train1_x)))
print("\nPredictions on Test: \n {}".format(model1.predict(test1_x)))
# Out:
# Predictions on Train:
#  [ 961.43524962 1440.37679382 3178.6306441  ... 1140.37431548 2632.95331726
#  2549.27325467]
#
# Predictions on Test:
#  [ 2024.15850409  3449.67415267  3191.24561116  3132.21447529
#   2564.32382833  4262.85474309  2731.48140188  1246.37175413
#   4304.598721     911.72890415  1944.87905782  1236.54613053
#    346.85611141  2514.77923556  2739.13822488  1951.63533565
#   2201.31305587  2108.3417927   1844.28343266  3668.93771332
#    595.02667086  1194.53936445  2561.53836349  3017.23184393
#   1861.04032785  2002.24954109   198.70049464  1788.02191267
#   2887.32181988  2458.46694006  1506.89543162  2724.8279159
#   2671.54516749   558.60435052  4368.08700444  2177.21536262
#   2338.45193639  2709.04615479  2320.51583508  3795.53111294
#   2009.28356016   860.64284239  -673.9999688   1175.83645313
#    294.68957862  2379.37770358  4258.20010309  2563.61851454
#   1336.67195949  -657.17660122  2167.21291042  4371.64888233
# ...

# %%
#Analysis of performance metrics on both train and test data
print("RMSE for Train: {}".format(mean_squared_error(train_y, model1.predict(train1_x))**0.5))
print("RMSE for Test: {}".format(mean_squared_error(test_y, model1.predict(test1_x))**0.5))
# Out:
# RMSE for Train: 1159.9746758023855
# RMSE for Test: 1014.4118022923625

# %% [markdown]
# Haalaanki (Although) there hasn't been much improvement in the RMSE for this dataset but this is a very good method to find and plot the most important independent variables which should be used while predicting the outcome.
